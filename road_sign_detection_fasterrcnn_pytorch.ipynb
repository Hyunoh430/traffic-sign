# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyunoh430/traffic-sign/blob/main/road_sign_detection_fasterrcnn_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Datasets and DataLoaders

# %% [markdown]
# ### Transformations

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install xmltodict
import os, cv2, random, xmltodict, torch, pandas as pd, numpy as np
from glob import glob
from PIL import Image
from torch.utils.data import random_split, Dataset, DataLoader
from matplotlib import pyplot as plt

class ObjectDetectionCustomDataset(Dataset):

    def __init__(self, root, transformations = None, size = 224, im_files = [".jpg", ".png", ".jpeg"]):

        self.root, self.size, self.transformations = root, size, transformations
        self.class_names, self.class_counts = {}, 0
        self.data_info = sorted(glob(f"{root}/annotations/*.xml"))

        for idx, data_info in enumerate(self.data_info):

            info = xmltodict.parse(open(f"{data_info}","r").read())

            bbox_info = info["annotation"]["object"]
            if isinstance(bbox_info, list):
                for bb_info in bbox_info:
                    if class_name not in self.class_names: self.class_names[class_name] = self.class_counts; self.class_counts += 1

            elif isinstance(bbox_info, dict):
                for bb_info in bbox_info:
                    class_name = bbox_info["name"]
                    if class_name not in self.class_names: self.class_names[class_name] = self.class_counts; self.class_counts += 1

    def __len__(self): return len(self.data_info)

    def get_info(self, idx): return xmltodict.parse(open(f"{self.data_info[idx]}","r").read())

    def read_im(self, info): return Image.open(f"{self.root}/images/{info['annotation']['filename']}").convert("RGB")

    def get_coordinates(self, bbox): return float(bbox["xmin"]), float(bbox["ymin"]), float(bbox["xmax"]), float(bbox["ymax"])

    def get_bboxes(self, info):

        bboxes, class_names = [], []
        bbox_info = info["annotation"]["object"]

        if isinstance(bbox_info, list):
            for bb_info in bbox_info:
                bbox = bb_info["bndbox"]
                class_name = bb_info["name"]
                class_names.append(class_name)
                bboxes.append(self.get_coordinates(bbox))

        elif isinstance(bbox_info, dict):
            for bb_info in bbox_info:
                if bb_info == "bndbox":
                    bbox = bbox_info[bb_info]
                    class_name = bbox_info["name"]
                    bboxes.append(self.get_coordinates(bbox))
                    class_names.append(class_name)

        return torch.as_tensor(bboxes, dtype = torch.float32), class_names

    def get_label(self, class_name): return self.class_names[class_name]

    def get_area(self, bboxes): return (bboxes[:, 3] - bboxes[:, 1]) * (bboxes[:, 2] - bboxes[:, 0])

    def create_target(self, bboxes, labels, rasm_id, area, is_crowd): target = {}; target["boxes"] = bboxes; target["labels"] = labels; target["image_id"] = rasm_id; target["area"] = area; target["iscrowd"] = is_crowd; return target

    def __getitem__(self, idx):

        info = self.get_info(idx)
        im = self.read_im(info)
        bboxes, class_names = self.get_bboxes(info)
        labels = torch.tensor([self.get_label(class_name) for class_name in class_names], dtype = torch.int64)

        rasm_id = torch.tensor([idx])
        area = self.get_area(bboxes)
        is_crowd = torch.zeros((len(bboxes), ), dtype = torch.int64)

        target = self.create_target(bboxes, labels, rasm_id, area, is_crowd)

        if self.transformations is not None: im, target = self.transformations(im, target)

        return im, target

def custom_collate_fn(batch): return tuple(zip(*batch))

def get_dls(root, transformations, bs, split = [0.8, 0.1], ns = 4):

    ds = ObjectDetectionCustomDataset(root = root, transformations = transformations)

    all_len = len(ds); tr_len = int(all_len * split[0]); val_len = int(all_len * split[1])
    tr_ds, val_ds, ts_ds = random_split(dataset = ds, lengths = [tr_len, val_len, all_len - tr_len - val_len])

    tr_dl, val_dl, ts_dl = DataLoader(tr_ds, batch_size = bs, collate_fn = custom_collate_fn, shuffle = True, num_workers = ns), DataLoader(val_ds, batch_size = bs, collate_fn = custom_collate_fn, shuffle = False, num_workers = ns), DataLoader(ts_ds, batch_size = 1, collate_fn = custom_collate_fn, shuffle = False, num_workers = ns)

    return tr_dl, val_dl, ts_dl, ds.class_names
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
from torch import Tensor
from torchvision.transforms import functional as F, transforms as T
from typing import Dict, Optional, Tuple, List

class Compose:
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

class PILToTensor(torch.nn.Module):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.pil_to_tensor(image)
        return image, target

class Normalize(torch.nn.Module):
    def forward(self, image: Tensor, target: Optional, mean: List[float] = [0.485, 0.456, 0.406], std: List[float] = [0.229, 0.224, 0.225]):
        image = F.normalize(tensor = image, mean = mean, std = std)
        return image, target

class ConvertImageDtype(torch.nn.Module):
    def __init__(self, dtype: torch.dtype) -> None:
        super().__init__()
        self.dtype = dtype

    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.convert_image_dtype(image, self.dtype)
        return image, target

class RandomHorizontalFlip(T.RandomHorizontalFlip):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        if torch.rand(1) < self.p:
            image = F.hflip(image)
            if target is not None:
                _, _, width = F.get_dimensions(image)
                if "masks" in target:
                    target["masks"] = target["masks"].flip(-1)
                if "keypoints" in target:
                    keypoints = target["keypoints"]
                    keypoints = _flip_coco_person_keypoints(keypoints, width)
                    target["keypoints"] = keypoints
        return image, target

def get_transform(train):

    transformations = []
    transformations.append(PILToTensor())
    transformations.append(ConvertImageDtype(torch.float))
    transformations.append(Normalize())

    if train: transformations.append(RandomHorizontalFlip(0.5))

    return Compose(transformations)

tfs = get_transform(train = False)
data_path = "/content/drive/MyDrive/Colab_Notebooks/traffic-sign/road-sign-detection"
tr_dl, val_dl, ts_dl, class_names = get_dls(root = data_path, transformations = tfs, bs = 4)
print(len(tr_dl), len(val_dl), len(ts_dl), class_names)
# Out:
# 176 22 89 {'trafficlight': 0, 'speedlimit': 1, 'crosswalk': 2, 'stop': 3}

# %% [markdown]
# ### Data Visualization

# %%
def tensor_2_im(t, t_type = "rgb", inv_trans = False):

    assert t_type in ["rgb", "gray"], "Rasm RGB yoki grayscale ekanligini aniqlashtirib bering."
    gray_tfs = T.Compose([T.Normalize(mean = [ 0.], std = [1/0.5]), T.Normalize(mean = [-0.5], std = [1])])
    rgb_tfs  = T.Compose([T.Normalize(mean = [ 0., 0., 0. ], std = [ 1/0.229, 1/0.224, 1/0.225 ]), T.Normalize(mean = [ -0.485, -0.456, -0.406 ], std = [ 1., 1., 1. ])])

    invTrans = gray_tfs if t_type == "gray" else rgb_tfs

    return (invTrans(t) * 255).detach().cpu().permute(1,2,0).numpy().astype(np.uint8) if inv_trans else (t * 255).detach().cpu().permute(1,2,0).numpy().astype(np.uint8)

def visualize(data, n_ims, rows, cmap = None):

    assert cmap in ["rgb", "gray"], "Rasmni oq-qora yoki rangli ekanini aniqlashtirib bering!"
    if cmap == "rgb": cmap = "viridis"

    plt.figure(figsize = (20, 10))
    indekslar = [random.randint(0, len(data) - 1) for _ in range(n_ims)]
    for idx, indeks in enumerate(indekslar):
        im, target = data[indeks]
        img = tensor_2_im(im, inv_trans = True)
        bbox_class_names = []
        for i, cntr in enumerate(target["boxes"]):
            r, g, b = [random.randint(0, 255) for _ in range(3)]
            x, y, w, h = [round(c.item()) for c in cntr]
            bbox_class_names.append(list(class_names.keys())[target["labels"][i].item()])
            cv2.rectangle(img = img, pt1 = (x, y), pt2 = (w, h), color = (r, g, b), thickness = 2)
        bbox_class_names = [bbox_class_name for bbox_class_name in bbox_class_names]
        plt.subplot(rows, n_ims // rows, idx + 1)

        plt.imshow(img); plt.title(f"{bbox_class_names}")

        plt.axis("off")

visualize(tr_dl.dataset, 20, 4, "rgb")

# %% [markdown]
# ### AI Model

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn

m = fasterrcnn_resnet50_fpn(weights = "DEFAULT")
device, num_classes = "cuda", len(class_names)

# get number of input features for the classifier
in_features = m.roi_heads.box_predictor.cls_score.in_features
# replace the pre-trained head with a new one
m.roi_heads.box_predictor.cls_score = torch.nn.Linear(in_features, num_classes)
m.roi_heads.box_predictor.bbox_pred = torch.nn.Linear(in_features, num_classes * 4)
m.to(device)
optimizer = torch.optim.SGD(m.parameters(), lr = 0.001, momentum = 0.9, weight_decay = 0.0005)
# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 3, gamma = 0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:00<00:00, 207MB/s]

# %% [markdown]
# ### Evaluation Metrics

# %%
# !pip install pycocotools
import torch.distributed as dist, datetime
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import pycocotools.mask as mask_util
from contextlib import redirect_stdout
import copy, io

class CocoEvaluator:
    def __init__(self, coco_gt, iou_types):
        if not isinstance(iou_types, (list, tuple)):
            raise TypeError(f"This constructor expects iou_types of type list or tuple, instead  got {type(iou_types)}")
        coco_gt = copy.deepcopy(coco_gt)
        self.coco_gt = coco_gt

        self.iou_types = iou_types
        self.coco_eval = {}
        for iou_type in iou_types:
            self.coco_eval[iou_type] = COCOeval(coco_gt, iouType=iou_type)

        self.img_ids = []
        self.eval_imgs = {k: [] for k in iou_types}

    def update(self, predictions):
        img_ids = list(np.unique(list(predictions.keys())))
        self.img_ids.extend(img_ids)

        for iou_type in self.iou_types:
            results = self.prepare(predictions, iou_type)
            with redirect_stdout(io.StringIO()):
                coco_dt = COCO.loadRes(self.coco_gt, results) if results else COCO()
            coco_eval = self.coco_eval[iou_type]

            coco_eval.cocoDt = coco_dt
            coco_eval.params.imgIds = list(img_ids)
            img_ids, eval_imgs = evaluate_coco(coco_eval)

            self.eval_imgs[iou_type].append(eval_imgs)

    def synchronize_between_processes(self):
        for iou_type in self.iou_types:
            self.eval_imgs[iou_type] = np.concatenate(self.eval_imgs[iou_type], 2)
            create_common_coco_eval(self.coco_eval[iou_type], self.img_ids, self.eval_imgs[iou_type])

    def accumulate(self):
        for coco_eval in self.coco_eval.values():
            coco_eval.accumulate()

    def summarize(self):
        for iou_type, coco_eval in self.coco_eval.items():
            print(f"IoU metric: {iou_type}")
            coco_eval.summarize()

    def prepare(self, predictions, iou_type):
        if iou_type == "bbox":
            return self.prepare_for_coco_detection(predictions)
        if iou_type == "segm":
            return self.prepare_for_coco_segmentation(predictions)
        if iou_type == "keypoints":
            return self.prepare_for_coco_keypoint(predictions)
        raise ValueError(f"Unknown iou type {iou_type}")

    def prepare_for_coco_detection(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            boxes = prediction["boxes"]
            boxes = convert_to_xywh(boxes).tolist()
            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "bbox": box,
                        "score": scores[k],
                    }
                    for k, box in enumerate(boxes)
                ]
            )
        return coco_results

    def prepare_for_coco_segmentation(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            scores = prediction["scores"]
            labels = prediction["labels"]
            masks = prediction["masks"]

            masks = masks > 0.5

            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()

            rles = [
                mask_util.encode(np.array(mask[0, :, :, np.newaxis], dtype=np.uint8, order="F"))[0] for mask in masks
            ]
            for rle in rles:
                rle["counts"] = rle["counts"].decode("utf-8")

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "segmentation": rle,
                        "score": scores[k],
                    }
                    for k, rle in enumerate(rles)
                ]
            )
        return coco_results

    def prepare_for_coco_keypoint(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            boxes = prediction["boxes"]
            boxes = convert_to_xywh(boxes).tolist()
            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()
            keypoints = prediction["keypoints"]
            keypoints = keypoints.flatten(start_dim=1).tolist()

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "keypoints": keypoint,
                        "score": scores[k],
                    }
                    for k, keypoint in enumerate(keypoints)
                ]
            )
        return coco_results


def convert_to_xywh(boxes):
    xmin, ymin, xmax, ymax = boxes.unbind(1)
    return torch.stack((xmin, ymin, xmax - xmin, ymax - ymin), dim=1)


def merge(img_ids, eval_imgs):
    all_img_ids = all_gather(img_ids)
    all_eval_imgs = all_gather(eval_imgs)

    merged_img_ids = []
    for p in all_img_ids:
        merged_img_ids.extend(p)

    merged_eval_imgs = []
    for p in all_eval_imgs:
        merged_eval_imgs.append(p)

    merged_img_ids = np.array(merged_img_ids)
    merged_eval_imgs = np.concatenate(merged_eval_imgs, 2)

    # keep only unique (and in sorted order) images
    merged_img_ids, idx = np.unique(merged_img_ids, return_index=True)
    merged_eval_imgs = merged_eval_imgs[..., idx]

    return merged_img_ids, merged_eval_imgs


def create_common_coco_eval(coco_eval, img_ids, eval_imgs):
    img_ids, eval_imgs = merge(img_ids, eval_imgs)
    img_ids = list(img_ids)
    eval_imgs = list(eval_imgs.flatten())

    coco_eval.evalImgs = eval_imgs
    coco_eval.params.imgIds = img_ids
    coco_eval._paramsEval = copy.deepcopy(coco_eval.params)


def evaluate_coco(imgs):
    with redirect_stdout(io.StringIO()):
        imgs.evaluate()
    return imgs.params.imgIds, np.asarray(imgs.evalImgs).reshape(-1, len(imgs.params.areaRng), len(imgs.params.imgIds))


def all_gather(data):
    """
    Run all_gather on arbitrary picklable data (not necessarily tensors)
    Args:
        data: any picklable object
    Returns:
        list[data]: list of data gathered from each rank
    """
    world_size = get_world_size()
    if world_size == 1:
        return [data]
    data_list = [None] * world_size
    dist.all_gather_object(data_list, data)
    return data_list
# Out:
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
import math, sys, time, torch, torchvision
import torchvision.models.detection.mask_rcnn
from pycocotools.coco import COCO
from pycocotools import mask as coco_mask
from collections import defaultdict, deque

def convert_to_coco_api(ds):
    coco_ds = COCO()
    # annotation IDs need to start at 1, not 0, see torchvision issue #1530
    ann_id = 1
    dataset = {"images": [], "categories": [], "annotations": []}
    categories = set()
    for img_idx in range(len(ds)):
        # find better way to get target
        # targets = ds.get_annotations(img_idx)
        img, targets = ds[img_idx]
        image_id = targets["image_id"].item()
        img_dict = {}
        img_dict["id"] = image_id
        img_dict["height"] = img.shape[-2]
        img_dict["width"] = img.shape[-1]
        dataset["images"].append(img_dict)
        bboxes = targets["boxes"].clone()
        bboxes[:, 2:] -= bboxes[:, :2]
        bboxes = bboxes.tolist()
        labels = targets["labels"].tolist()
        areas = targets["area"].tolist()
        iscrowd = targets["iscrowd"].tolist()
        if "masks" in targets:
            masks = targets["masks"]
            # make masks Fortran contiguous for coco_mask
            masks = masks.permute(0, 2, 1).contiguous().permute(0, 2, 1)
        if "keypoints" in targets:
            keypoints = targets["keypoints"]
            keypoints = keypoints.reshape(keypoints.shape[0], -1).tolist()
        num_objs = len(bboxes)
        for i in range(num_objs):
            ann = {}
            ann["image_id"] = image_id
            ann["bbox"] = bboxes[i]
            ann["category_id"] = labels[i]
            categories.add(labels[i])
            ann["area"] = areas[i]
            ann["iscrowd"] = iscrowd[i]
            ann["id"] = ann_id
            if "masks" in targets:
                ann["segmentation"] = coco_mask.encode(masks[i].numpy())
            if "keypoints" in targets:
                ann["keypoints"] = keypoints[i]
                ann["num_keypoints"] = sum(k != 0 for k in keypoints[i][2::3])
            dataset["annotations"].append(ann)
            ann_id += 1
    dataset["categories"] = [{"id": i} for i in sorted(categories)]
    coco_ds.dataset = dataset
    coco_ds.createIndex()
    return coco_ds

def get_coco_api_from_dataset(dataset):
    for _ in range(10):
        if isinstance(dataset, torchvision.datasets.CocoDetection):
            break
        if isinstance(dataset, torch.utils.data.Subset):
            dataset = dataset.dataset
    if isinstance(dataset, torchvision.datasets.CocoDetection):
        return dataset.coco
    return convert_to_coco_api(dataset)

def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq, scaler = None):
    model.train()
    metric_logger = MetricLogger(delimiter=" | ")
    metric_logger.add_meter("lr", SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"{epoch + 1}-epochdagi "

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1.0 / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = torch.optim.lr_scheduler.LinearLR(
            optimizer, start_factor=warmup_factor, total_iters=warmup_iters
        )

    for idx, (images, targets) in enumerate(metric_logger.log_every(data_loader, print_freq, header)):
        images = list(image.to(device) for image in images)

        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]  # change here

        # targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        with torch.cuda.amp.autocast(enabled=scaler is not None):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print(f"Loss {loss_value} bo'lgani uchun train jarayonini to'xtatamiz...")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        if scaler is not None:
            scaler.scale(losses).backward()
            scaler.step(optimizer)
            scaler.update()
        else:
            losses.backward()
            optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

def _get_iou_types(model):
    model_without_ddp = model
    if isinstance(model, torch.nn.parallel.DistributedDataParallel):
        model_without_ddp = model.module
    iou_types = ["bbox"]
    if isinstance(model_without_ddp, torchvision.models.detection.MaskRCNN):
        iou_types.append("segm")
    if isinstance(model_without_ddp, torchvision.models.detection.KeypointRCNN):
        iou_types.append("keypoints")
    return iou_types

# @torch.inference_mode()
def evaluate(model, data_loader, device):
    n_threads = torch.get_num_threads()
    # FIXME remove this and make paste_masks_in_image run on the GPU
    torch.set_num_threads(1)
    cpu_device = torch.device("cpu")
    model.eval()
    metric_logger = MetricLogger(delimiter=" | ")
    header = "Test jarayoni: "

    coco = get_coco_api_from_dataset(data_loader.dataset)
    iou_types = _get_iou_types(model)
    coco_evaluator = CocoEvaluator(coco, iou_types)

    for images, targets in metric_logger.log_every(data_loader, 100, header):

        images = list(img.to(device) for img in images)

        if torch.cuda.is_available(): torch.cuda.synchronize()
        model_time = time.time()
        outputs = model(images)

        outputs = [{k: v.to(cpu_device) for k, v in t.items()} for t in outputs]
        model_time = time.time() - model_time

        res = {target["image_id"].item(): output for target, output in zip(targets, outputs)}
        evaluator_time = time.time()
        coco_evaluator.update(res)
        evaluator_time = time.time() - evaluator_time
        metric_logger.update(model_vaqt=model_time, baholash_vaqt=evaluator_time)

    # gather the stats from all processes
    metric_logger.synchronize_between_processes()
    print(f"\nTest jarayoni statistikasi: {metric_logger}\n")
    coco_evaluator.synchronize_between_processes()

    # accumulate predictions from all images
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
    torch.set_num_threads(n_threads)

    return coco_evaluator

class SmoothedValue:
    """Track a series of values and provide access to smoothed values over a
    window or the global series average.
    """

    def __init__(self, window_size=20, fmt=None):
        if fmt is None:
            fmt = "{median:.4f} ({global_avg:.4f})"
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    def synchronize_between_processes(self):
        """
        Warning: does not synchronize the deque!
        """
        if not is_dist_avail_and_initialized():
            return
        t = torch.tensor([self.count, self.total], dtype=torch.float64, device="cuda")
        dist.barrier()
        dist.all_reduce(t)
        t = t.tolist()
        self.count = int(t[0])
        self.total = t[1]

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count

    @property
    def max(self):
        return max(self.deque)

    @property
    def value(self):
        return self.deque[-1]

    def __str__(self):
        return self.fmt.format(
            median=self.median, avg=self.avg, global_avg=self.global_avg, max=self.max, value=self.value
        )

class MetricLogger:
    def __init__(self, delimiter=" | "):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            assert isinstance(v, (float, int))
            self.meters[k].update(v)

    def __getattr__(self, attr):
        if attr in self.meters:
            return self.meters[attr]
        if attr in self.__dict__:
            return self.__dict__[attr]
        raise AttributeError(f"'{type(self).__name__}' object has no attribute '{attr}'")

    def __str__(self):
        loss_str = []
        for name, meter in self.meters.items():
            loss_str.append(f"{name}: {str(meter)}")
        return self.delimiter.join(loss_str)

    def synchronize_between_processes(self):
        for meter in self.meters.values():
            meter.synchronize_between_processes()

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        if not header:
            header = ""
        start_time = time.time()
        end = time.time()
        iter_time = SmoothedValue(fmt="{avg:.4f}")
        data_time = SmoothedValue(fmt="{avg:.4f}")
        space_fmt = ":" + str(len(str(len(iterable)))) + "d"
        if torch.cuda.is_available():
            init_msg = "".join(
                [
                    f"\n{header}",
                    "{1}ta batchdan {0" + space_fmt +"}-sining natijasi: \n",
                ]
            )

            log_msg = self.delimiter.join(
                [
                    "{meters}",
                    "vaqt -> {time}",
                ]
            )
        else:
            log_msg = self.delimiter.join(
                [header, "[{0" + space_fmt + "}/{1}]", "eta: {eta}", "{meters}", "vaqt: {vaqt}", "data: {data}"]
            )
        MB = 1024.0 * 1024.0
        for obj in iterable:
            data_time.update(time.time() - end)
            yield obj
            iter_time.update(time.time() - end)
            if i % print_freq == 0 or i == len(iterable) - 1:
                eta_seconds = iter_time.global_avg * (len(iterable) - i)
                eta_string = str(datetime.timedelta(seconds=int(eta_seconds)))
                if torch.cuda.is_available():
                    print(init_msg.format(i + 1, len(iterable)))
                    print(
                        log_msg.format(
                            meters=str(self),
                            time=str(iter_time),
                        )
                    )
                else:
                    print(
                        log_msg.format(
                            i, len(iterable), eta=eta_string, meters=str(self), time=str(iter_time), data=str(data_time)
                        )
                    )
            i += 1
            end = time.time()
        total_time = time.time() - start_time
        total_time_str = str(datetime.timedelta(seconds=int(total_time)))
        print(f"{header} umumiy vaqt: {total_time_str} ({total_time / len(iterable):.4f} s / rasm)")

def reduce_dict(input_dict, average=True):
    """
    Args:
        input_dict (dict): all the values will be reduced
        average (bool): whether to do average or sum
    Reduce the values in the dictionary from all processes so that all processes
    have the averaged results. Returns a dict with the same fields as
    input_dict, after reduction.
    """
    world_size = get_world_size()
    if world_size < 2:
        return input_dict
    with torch.inference_mode():
        names = []
        values = []
        # sort the keys so that they are consistent across processes
        for k in sorted(input_dict.keys()):
            names.append(k)
            values.append(input_dict[k])
        values = torch.stack(values, dim=0)
        dist.all_reduce(values)
        if average:
            values /= world_size
        reduced_dict = {k: v for k, v in zip(names, values)}
    return reduced_dict

def get_world_size():
    if not is_dist_avail_and_initialized():
        return 1
    return dist.get_world_size()

def is_dist_avail_and_initialized():
    if not dist.is_available():
        return False
    if not dist.is_initialized():
        return False
    return True

# %% [markdown]
# ### Train and Validation

# %%
model_prefix = "road"
epochs = 10
save_model_path = "/content/drive/MyDrive/Colab_Notebooks/traffic-sign"
for epoch in range(epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(m, optimizer, tr_dl, device, epoch, print_freq = 10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(m, val_dl, device = device)

os.makedirs(f"{save_model_path}", exist_ok = True)
torch.save(m, f"{save_model_path}/{model_prefix}_best_model.pt")
print("Train jarayoni yakunlandi!")
# Out:
# <ipython-input-7-ba137c0652ec>:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# 1-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000007 | loss: 0.0860 (0.0860) | loss_classifier: 0.0267 (0.0267) | loss_box_reg: 0.0574 (0.0574) | loss_objectness: 0.0002 (0.0002) | loss_rpn_box_reg: 0.0017 (0.0017) | vaqt -> 1.5947
#
# 1-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000064 | loss: 0.0860 (0.0996) | loss_classifier: 0.0310 (0.0352) | loss_box_reg: 0.0491 (0.0490) | loss_objectness: 0.0012 (0.0129) | loss_rpn_box_reg: 0.0017 (0.0025) | vaqt -> 1.1843
#
# 1-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000121 | loss: 0.0796 (0.1068) | loss_classifier: 0.0310 (0.0386) | loss_box_reg: 0.0432 (0.0579) | loss_objectness: 0.0011 (0.0076) | loss_rpn_box_reg: 0.0020 (0.0026) | vaqt -> 1.2348
#
# 1-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000178 | loss: 0.0791 (0.1008) | loss_classifier: 0.0266 (0.0365) | loss_box_reg: 0.0463 (0.0559) | loss_objectness: 0.0010 (0.0056) | loss_rpn_box_reg: 0.0022 (0.0029) | vaqt -> 1.2573
#
# 1-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000235 | loss: 0.0780 (0.0971) | loss_classifier: 0.0291 (0.0354) | loss_box_reg: 0.0471 (0.0542) | loss_objectness: 0.0010 (0.0047) | loss_rpn_box_reg: 0.0013 (0.0027) | vaqt -> 1.2398
#
# 1-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000292 | loss: 0.0690 (0.0933) | loss_classifier: 0.0298 (0.0343) | loss_box_reg: 0.0430 (0.0522) | loss_objectness: 0.0010 (0.0041) | loss_rpn_box_reg: 0.0012 (0.0027) | vaqt -> 1.2936
#
# 1-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000349 | loss: 0.0758 (0.0902) | loss_classifier: 0.0229 (0.0329) | loss_box_reg: 0.0433 (0.0511) | loss_objectness: 0.0010 (0.0037) | loss_rpn_box_reg: 0.0013 (0.0025) | vaqt -> 1.2392
#
# 1-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000406 | loss: 0.0712 (0.0880) | loss_classifier: 0.0229 (0.0317) | loss_box_reg: 0.0433 (0.0500) | loss_objectness: 0.0007 (0.0037) | loss_rpn_box_reg: 0.0012 (0.0025) | vaqt -> 1.1733
#
# 1-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000463 | loss: 0.0622 (0.0863) | loss_classifier: 0.0196 (0.0310) | loss_box_reg: 0.0373 (0.0491) | loss_objectness: 0.0005 (0.0037) | loss_rpn_box_reg: 0.0014 (0.0025) | vaqt -> 1.1340
#
# 1-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000520 | loss: 0.0760 (0.0855) | loss_classifier: 0.0242 (0.0308) | loss_box_reg: 0.0428 (0.0487) | loss_objectness: 0.0004 (0.0035) | loss_rpn_box_reg: 0.0014 (0.0024) | vaqt -> 1.1545
#
# 1-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000578 | loss: 0.0803 (0.0851) | loss_classifier: 0.0259 (0.0304) | loss_box_reg: 0.0428 (0.0488) | loss_objectness: 0.0003 (0.0036) | loss_rpn_box_reg: 0.0016 (0.0023) | vaqt -> 1.2677
#
# 1-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000635 | loss: 0.0630 (0.0834) | loss_classifier: 0.0208 (0.0296) | loss_box_reg: 0.0381 (0.0481) | loss_objectness: 0.0002 (0.0034) | loss_rpn_box_reg: 0.0016 (0.0023) | vaqt -> 1.2390
#
# 1-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000692 | loss: 0.0630 (0.0829) | loss_classifier: 0.0214 (0.0294) | loss_box_reg: 0.0378 (0.0478) | loss_objectness: 0.0007 (0.0033) | loss_rpn_box_reg: 0.0016 (0.0023) | vaqt -> 1.1977
#
# 1-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000749 | loss: 0.0628 (0.0812) | loss_classifier: 0.0178 (0.0286) | loss_box_reg: 0.0360 (0.0468) | loss_objectness: 0.0008 (0.0035) | loss_rpn_box_reg: 0.0018 (0.0023) | vaqt -> 1.2384
#
# 1-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000806 | loss: 0.0628 (0.0812) | loss_classifier: 0.0174 (0.0284) | loss_box_reg: 0.0377 (0.0469) | loss_objectness: 0.0009 (0.0037) | loss_rpn_box_reg: 0.0011 (0.0023) | vaqt -> 1.2139
#
# 1-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000863 | loss: 0.0576 (0.0799) | loss_classifier: 0.0185 (0.0280) | loss_box_reg: 0.0368 (0.0462) | loss_objectness: 0.0009 (0.0036) | loss_rpn_box_reg: 0.0010 (0.0022) | vaqt -> 1.1895
#
# 1-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000920 | loss: 0.0506 (0.0788) | loss_classifier: 0.0197 (0.0278) | loss_box_reg: 0.0311 (0.0455) | loss_objectness: 0.0006 (0.0034) | loss_rpn_box_reg: 0.0009 (0.0022) | vaqt -> 1.1635
#
# 1-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000977 | loss: 0.0709 (0.0783) | loss_classifier: 0.0231 (0.0275) | loss_box_reg: 0.0386 (0.0454) | loss_objectness: 0.0001 (0.0032) | loss_rpn_box_reg: 0.0012 (0.0021) | vaqt -> 1.1981
#
# 1-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.001000 | loss: 0.0563 (0.0775) | loss_classifier: 0.0189 (0.0272) | loss_box_reg: 0.0319 (0.0450) | loss_objectness: 0.0003 (0.0032) | loss_rpn_box_reg: 0.0011 (0.0021) | vaqt -> 1.1896
# 1-epochdagi  umumiy vaqt: 0:03:32 (1.2100 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6680 (0.6680) | baholash_vaqt: 0.0043 (0.0043) | vaqt -> 0.9014
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4836 (0.5266) | baholash_vaqt: 0.0031 (0.0032) | vaqt -> 0.5379
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5517 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4836 (0.5266) | baholash_vaqt: 0.0031 (0.0032)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.642
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.581
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.533
#
# 2-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.001000 | loss: 0.0650 (0.0650) | loss_classifier: 0.0294 (0.0294) | loss_box_reg: 0.0345 (0.0345) | loss_objectness: 0.0000 (0.0000) | loss_rpn_box_reg: 0.0011 (0.0011) | vaqt -> 1.5629
#
# 2-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.001000 | loss: 0.0704 (0.0817) | loss_classifier: 0.0242 (0.0300) | loss_box_reg: 0.0460 (0.0479) | loss_objectness: 0.0005 (0.0015) | loss_rpn_box_reg: 0.0011 (0.0022) | vaqt -> 1.3229
#
# 2-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.001000 | loss: 0.0704 (0.0811) | loss_classifier: 0.0231 (0.0287) | loss_box_reg: 0.0460 (0.0485) | loss_objectness: 0.0009 (0.0019) | loss_rpn_box_reg: 0.0011 (0.0019) | vaqt -> 1.2800
#
# 2-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.001000 | loss: 0.0636 (0.0779) | loss_classifier: 0.0213 (0.0271) | loss_box_reg: 0.0385 (0.0472) | loss_objectness: 0.0009 (0.0018) | loss_rpn_box_reg: 0.0007 (0.0018) | vaqt -> 1.1995
#
# 2-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.001000 | loss: 0.0577 (0.0762) | loss_classifier: 0.0172 (0.0253) | loss_box_reg: 0.0369 (0.0476) | loss_objectness: 0.0003 (0.0016) | loss_rpn_box_reg: 0.0009 (0.0017) | vaqt -> 1.1529
#
# 2-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.001000 | loss: 0.0648 (0.0758) | loss_classifier: 0.0184 (0.0253) | loss_box_reg: 0.0390 (0.0471) | loss_objectness: 0.0004 (0.0016) | loss_rpn_box_reg: 0.0015 (0.0019) | vaqt -> 1.1587
#
# 2-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.001000 | loss: 0.0648 (0.0739) | loss_classifier: 0.0209 (0.0252) | loss_box_reg: 0.0384 (0.0453) | loss_objectness: 0.0005 (0.0016) | loss_rpn_box_reg: 0.0015 (0.0019) | vaqt -> 1.1998
#
# 2-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.001000 | loss: 0.0647 (0.0748) | loss_classifier: 0.0201 (0.0246) | loss_box_reg: 0.0392 (0.0446) | loss_objectness: 0.0005 (0.0036) | loss_rpn_box_reg: 0.0020 (0.0020) | vaqt -> 1.2527
#
# 2-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.001000 | loss: 0.0647 (0.0734) | loss_classifier: 0.0216 (0.0245) | loss_box_reg: 0.0392 (0.0434) | loss_objectness: 0.0022 (0.0034) | loss_rpn_box_reg: 0.0016 (0.0021) | vaqt -> 1.2009
#
# 2-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.001000 | loss: 0.0648 (0.0729) | loss_classifier: 0.0183 (0.0239) | loss_box_reg: 0.0371 (0.0434) | loss_objectness: 0.0019 (0.0035) | loss_rpn_box_reg: 0.0011 (0.0020) | vaqt -> 1.2045
#
# 2-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.001000 | loss: 0.0592 (0.0709) | loss_classifier: 0.0183 (0.0235) | loss_box_reg: 0.0354 (0.0423) | loss_objectness: 0.0005 (0.0032) | loss_rpn_box_reg: 0.0010 (0.0020) | vaqt -> 1.1855
#
# 2-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.001000 | loss: 0.0459 (0.0692) | loss_classifier: 0.0164 (0.0228) | loss_box_reg: 0.0287 (0.0415) | loss_objectness: 0.0003 (0.0030) | loss_rpn_box_reg: 0.0010 (0.0019) | vaqt -> 1.0995
#
# 2-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.001000 | loss: 0.0527 (0.0689) | loss_classifier: 0.0161 (0.0227) | loss_box_reg: 0.0378 (0.0415) | loss_objectness: 0.0003 (0.0029) | loss_rpn_box_reg: 0.0010 (0.0018) | vaqt -> 1.1581
#
# 2-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.001000 | loss: 0.0639 (0.0683) | loss_classifier: 0.0183 (0.0225) | loss_box_reg: 0.0409 (0.0412) | loss_objectness: 0.0002 (0.0028) | loss_rpn_box_reg: 0.0012 (0.0018) | vaqt -> 1.2540
#
# 2-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.001000 | loss: 0.0468 (0.0671) | loss_classifier: 0.0156 (0.0221) | loss_box_reg: 0.0328 (0.0405) | loss_objectness: 0.0003 (0.0026) | loss_rpn_box_reg: 0.0011 (0.0018) | vaqt -> 1.2616
#
# 2-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.001000 | loss: 0.0431 (0.0664) | loss_classifier: 0.0137 (0.0218) | loss_box_reg: 0.0304 (0.0402) | loss_objectness: 0.0003 (0.0025) | loss_rpn_box_reg: 0.0009 (0.0018) | vaqt -> 1.2625
#
# 2-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.001000 | loss: 0.0543 (0.0663) | loss_classifier: 0.0177 (0.0218) | loss_box_reg: 0.0371 (0.0402) | loss_objectness: 0.0003 (0.0025) | loss_rpn_box_reg: 0.0013 (0.0018) | vaqt -> 1.2501
#
# 2-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.001000 | loss: 0.0614 (0.0653) | loss_classifier: 0.0158 (0.0214) | loss_box_reg: 0.0389 (0.0397) | loss_objectness: 0.0004 (0.0024) | loss_rpn_box_reg: 0.0009 (0.0018) | vaqt -> 1.1980
#
# 2-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.001000 | loss: 0.0503 (0.0646) | loss_classifier: 0.0156 (0.0211) | loss_box_reg: 0.0318 (0.0393) | loss_objectness: 0.0003 (0.0024) | loss_rpn_box_reg: 0.0011 (0.0018) | vaqt -> 1.1582
# 2-epochdagi  umumiy vaqt: 0:03:32 (1.2074 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6691 (0.6691) | baholash_vaqt: 0.0049 (0.0049) | vaqt -> 0.9080
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4794 (0.5270) | baholash_vaqt: 0.0029 (0.0031) | vaqt -> 0.5397
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5537 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4794 (0.5270) | baholash_vaqt: 0.0029 (0.0031)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.530
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.536
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.545
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.623
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.539
#
# 3-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000100 | loss: 0.1145 (0.1145) | loss_classifier: 0.0424 (0.0424) | loss_box_reg: 0.0656 (0.0656) | loss_objectness: 0.0041 (0.0041) | loss_rpn_box_reg: 0.0025 (0.0025) | vaqt -> 1.2812
#
# 3-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000100 | loss: 0.0404 (0.0567) | loss_classifier: 0.0154 (0.0190) | loss_box_reg: 0.0247 (0.0351) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0011 (0.0013) | vaqt -> 1.2260
#
# 3-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000100 | loss: 0.0404 (0.0541) | loss_classifier: 0.0141 (0.0184) | loss_box_reg: 0.0247 (0.0336) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0011) | vaqt -> 1.2444
#
# 3-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000100 | loss: 0.0462 (0.0526) | loss_classifier: 0.0153 (0.0180) | loss_box_reg: 0.0276 (0.0328) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0011) | vaqt -> 1.2519
#
# 3-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000100 | loss: 0.0396 (0.0491) | loss_classifier: 0.0153 (0.0169) | loss_box_reg: 0.0250 (0.0302) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0012) | vaqt -> 1.2509
#
# 3-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000100 | loss: 0.0378 (0.0500) | loss_classifier: 0.0126 (0.0170) | loss_box_reg: 0.0224 (0.0307) | loss_objectness: 0.0003 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0013) | vaqt -> 1.1883
#
# 3-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000100 | loss: 0.0520 (0.0517) | loss_classifier: 0.0189 (0.0177) | loss_box_reg: 0.0327 (0.0319) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0012) | vaqt -> 1.1315
#
# 3-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000100 | loss: 0.0520 (0.0512) | loss_classifier: 0.0179 (0.0173) | loss_box_reg: 0.0330 (0.0318) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0012) | vaqt -> 1.2053
#
# 3-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000100 | loss: 0.0449 (0.0514) | loss_classifier: 0.0150 (0.0173) | loss_box_reg: 0.0243 (0.0318) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.2276
#
# 3-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000100 | loss: 0.0471 (0.0516) | loss_classifier: 0.0115 (0.0173) | loss_box_reg: 0.0243 (0.0320) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.2240
#
# 3-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000100 | loss: 0.0479 (0.0518) | loss_classifier: 0.0147 (0.0173) | loss_box_reg: 0.0322 (0.0319) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0012 (0.0014) | vaqt -> 1.3012
#
# 3-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000100 | loss: 0.0475 (0.0519) | loss_classifier: 0.0147 (0.0175) | loss_box_reg: 0.0322 (0.0318) | loss_objectness: 0.0006 (0.0011) | loss_rpn_box_reg: 0.0011 (0.0015) | vaqt -> 1.2679
#
# 3-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000100 | loss: 0.0422 (0.0515) | loss_classifier: 0.0152 (0.0174) | loss_box_reg: 0.0248 (0.0316) | loss_objectness: 0.0003 (0.0011) | loss_rpn_box_reg: 0.0008 (0.0015) | vaqt -> 1.1922
#
# 3-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000100 | loss: 0.0429 (0.0510) | loss_classifier: 0.0137 (0.0172) | loss_box_reg: 0.0255 (0.0313) | loss_objectness: 0.0003 (0.0011) | loss_rpn_box_reg: 0.0008 (0.0015) | vaqt -> 1.2040
#
# 3-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000100 | loss: 0.0380 (0.0507) | loss_classifier: 0.0135 (0.0172) | loss_box_reg: 0.0240 (0.0310) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.1167
#
# 3-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000100 | loss: 0.0424 (0.0513) | loss_classifier: 0.0147 (0.0175) | loss_box_reg: 0.0264 (0.0313) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0006 (0.0014) | vaqt -> 1.1105
#
# 3-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000100 | loss: 0.0424 (0.0509) | loss_classifier: 0.0151 (0.0173) | loss_box_reg: 0.0268 (0.0311) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0015) | vaqt -> 1.2776
#
# 3-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000100 | loss: 0.0439 (0.0510) | loss_classifier: 0.0137 (0.0173) | loss_box_reg: 0.0276 (0.0312) | loss_objectness: 0.0003 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0015) | vaqt -> 1.2459
#
# 3-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.000100 | loss: 0.0439 (0.0509) | loss_classifier: 0.0141 (0.0173) | loss_box_reg: 0.0264 (0.0310) | loss_objectness: 0.0004 (0.0011) | loss_rpn_box_reg: 0.0013 (0.0015) | vaqt -> 1.1698
# 3-epochdagi  umumiy vaqt: 0:03:32 (1.2093 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6530 (0.6530) | baholash_vaqt: 0.0042 (0.0042) | vaqt -> 0.9155
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4871 (0.5266) | baholash_vaqt: 0.0028 (0.0031) | vaqt -> 0.5395
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5539 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4871 (0.5266) | baholash_vaqt: 0.0028 (0.0031)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.680
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.653
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.586
#
# 4-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000100 | loss: 0.0446 (0.0446) | loss_classifier: 0.0165 (0.0165) | loss_box_reg: 0.0277 (0.0277) | loss_objectness: 0.0000 (0.0000) | loss_rpn_box_reg: 0.0004 (0.0004) | vaqt -> 1.2412
#
# 4-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000100 | loss: 0.0500 (0.0514) | loss_classifier: 0.0156 (0.0170) | loss_box_reg: 0.0323 (0.0325) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0012) | vaqt -> 1.1767
#
# 4-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000100 | loss: 0.0512 (0.0625) | loss_classifier: 0.0175 (0.0205) | loss_box_reg: 0.0332 (0.0390) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0020) | vaqt -> 1.2487
#
# 4-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000100 | loss: 0.0521 (0.0592) | loss_classifier: 0.0211 (0.0202) | loss_box_reg: 0.0328 (0.0365) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0017) | vaqt -> 1.2908
#
# 4-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000100 | loss: 0.0480 (0.0568) | loss_classifier: 0.0175 (0.0192) | loss_box_reg: 0.0280 (0.0349) | loss_objectness: 0.0003 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0016) | vaqt -> 1.2173
#
# 4-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000100 | loss: 0.0396 (0.0556) | loss_classifier: 0.0175 (0.0191) | loss_box_reg: 0.0223 (0.0337) | loss_objectness: 0.0003 (0.0010) | loss_rpn_box_reg: 0.0012 (0.0017) | vaqt -> 1.1439
#
# 4-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000100 | loss: 0.0396 (0.0543) | loss_classifier: 0.0155 (0.0189) | loss_box_reg: 0.0223 (0.0328) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0016) | vaqt -> 1.1426
#
# 4-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000100 | loss: 0.0398 (0.0523) | loss_classifier: 0.0144 (0.0183) | loss_box_reg: 0.0232 (0.0317) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0006 (0.0015) | vaqt -> 1.2093
#
# 4-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000100 | loss: 0.0402 (0.0523) | loss_classifier: 0.0127 (0.0182) | loss_box_reg: 0.0269 (0.0318) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0015) | vaqt -> 1.2741
#
# 4-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000100 | loss: 0.0430 (0.0516) | loss_classifier: 0.0136 (0.0180) | loss_box_reg: 0.0271 (0.0312) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2066
#
# 4-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000100 | loss: 0.0457 (0.0523) | loss_classifier: 0.0141 (0.0181) | loss_box_reg: 0.0273 (0.0317) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0015) | vaqt -> 1.1743
#
# 4-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000100 | loss: 0.0446 (0.0517) | loss_classifier: 0.0154 (0.0180) | loss_box_reg: 0.0273 (0.0313) | loss_objectness: 0.0005 (0.0010) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.2077
#
# 4-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000100 | loss: 0.0473 (0.0518) | loss_classifier: 0.0156 (0.0180) | loss_box_reg: 0.0303 (0.0314) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.1865
#
# 4-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000100 | loss: 0.0491 (0.0517) | loss_classifier: 0.0179 (0.0181) | loss_box_reg: 0.0304 (0.0313) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.2182
#
# 4-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000100 | loss: 0.0471 (0.0510) | loss_classifier: 0.0160 (0.0178) | loss_box_reg: 0.0271 (0.0309) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.2112
#
# 4-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000100 | loss: 0.0437 (0.0506) | loss_classifier: 0.0143 (0.0176) | loss_box_reg: 0.0281 (0.0307) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.2274
#
# 4-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000100 | loss: 0.0390 (0.0501) | loss_classifier: 0.0136 (0.0174) | loss_box_reg: 0.0265 (0.0305) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0006 (0.0014) | vaqt -> 1.1903
#
# 4-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000100 | loss: 0.0402 (0.0497) | loss_classifier: 0.0130 (0.0172) | loss_box_reg: 0.0244 (0.0303) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.2259
#
# 4-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.000100 | loss: 0.0402 (0.0496) | loss_classifier: 0.0136 (0.0171) | loss_box_reg: 0.0263 (0.0302) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2619
# 4-epochdagi  umumiy vaqt: 0:03:33 (1.2129 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6699 (0.6699) | baholash_vaqt: 0.0048 (0.0048) | vaqt -> 0.9333
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4843 (0.5242) | baholash_vaqt: 0.0029 (0.0031) | vaqt -> 0.5355
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5510 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4843 (0.5242) | baholash_vaqt: 0.0029 (0.0031)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.555
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.680
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.647
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.575
#
# 5-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000100 | loss: 0.0415 (0.0415) | loss_classifier: 0.0151 (0.0151) | loss_box_reg: 0.0230 (0.0230) | loss_objectness: 0.0029 (0.0029) | loss_rpn_box_reg: 0.0006 (0.0006) | vaqt -> 1.2508
#
# 5-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000100 | loss: 0.0531 (0.0509) | loss_classifier: 0.0151 (0.0162) | loss_box_reg: 0.0361 (0.0322) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0013) | vaqt -> 1.2274
#
# 5-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000100 | loss: 0.0466 (0.0532) | loss_classifier: 0.0161 (0.0175) | loss_box_reg: 0.0280 (0.0332) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0011 (0.0015) | vaqt -> 1.2403
#
# 5-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000100 | loss: 0.0448 (0.0511) | loss_classifier: 0.0165 (0.0172) | loss_box_reg: 0.0260 (0.0317) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0013 (0.0014) | vaqt -> 1.2260
#
# 5-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000100 | loss: 0.0397 (0.0498) | loss_classifier: 0.0147 (0.0167) | loss_box_reg: 0.0271 (0.0308) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0013) | vaqt -> 1.1921
#
# 5-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000100 | loss: 0.0397 (0.0482) | loss_classifier: 0.0136 (0.0163) | loss_box_reg: 0.0247 (0.0295) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0013) | vaqt -> 1.1050
#
# 5-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000100 | loss: 0.0402 (0.0483) | loss_classifier: 0.0152 (0.0166) | loss_box_reg: 0.0245 (0.0293) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.1442
#
# 5-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000100 | loss: 0.0461 (0.0484) | loss_classifier: 0.0158 (0.0169) | loss_box_reg: 0.0265 (0.0293) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0006 (0.0013) | vaqt -> 1.2111
#
# 5-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000100 | loss: 0.0461 (0.0484) | loss_classifier: 0.0173 (0.0170) | loss_box_reg: 0.0263 (0.0292) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0005 (0.0013) | vaqt -> 1.1796
#
# 5-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000100 | loss: 0.0434 (0.0487) | loss_classifier: 0.0165 (0.0172) | loss_box_reg: 0.0263 (0.0293) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.3044
#
# 5-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000100 | loss: 0.0372 (0.0475) | loss_classifier: 0.0124 (0.0166) | loss_box_reg: 0.0251 (0.0288) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.3448
#
# 5-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000100 | loss: 0.0395 (0.0470) | loss_classifier: 0.0135 (0.0163) | loss_box_reg: 0.0245 (0.0286) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0013 (0.0014) | vaqt -> 1.2499
#
# 5-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000100 | loss: 0.0422 (0.0470) | loss_classifier: 0.0149 (0.0164) | loss_box_reg: 0.0230 (0.0285) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0013) | vaqt -> 1.1941
#
# 5-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000100 | loss: 0.0471 (0.0471) | loss_classifier: 0.0161 (0.0164) | loss_box_reg: 0.0310 (0.0286) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0013) | vaqt -> 1.2107
#
# 5-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000100 | loss: 0.0525 (0.0486) | loss_classifier: 0.0159 (0.0168) | loss_box_reg: 0.0340 (0.0297) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0008 (0.0013) | vaqt -> 1.2613
#
# 5-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000100 | loss: 0.0450 (0.0483) | loss_classifier: 0.0159 (0.0167) | loss_box_reg: 0.0291 (0.0295) | loss_objectness: 0.0001 (0.0007) | loss_rpn_box_reg: 0.0007 (0.0013) | vaqt -> 1.2620
#
# 5-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000100 | loss: 0.0433 (0.0480) | loss_classifier: 0.0141 (0.0166) | loss_box_reg: 0.0266 (0.0293) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0013) | vaqt -> 1.1993
#
# 5-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000100 | loss: 0.0455 (0.0485) | loss_classifier: 0.0143 (0.0167) | loss_box_reg: 0.0283 (0.0296) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0012 (0.0014) | vaqt -> 1.1868
#
# 5-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.000100 | loss: 0.0433 (0.0487) | loss_classifier: 0.0143 (0.0167) | loss_box_reg: 0.0283 (0.0298) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.1188
# 5-epochdagi  umumiy vaqt: 0:03:33 (1.2106 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6410 (0.6410) | baholash_vaqt: 0.0041 (0.0041) | vaqt -> 0.8900
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4795 (0.5248) | baholash_vaqt: 0.0029 (0.0031) | vaqt -> 0.5388
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5523 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4795 (0.5248) | baholash_vaqt: 0.0029 (0.0031)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.682
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.665
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.629
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.575
#
# 6-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000010 | loss: 0.0372 (0.0372) | loss_classifier: 0.0115 (0.0115) | loss_box_reg: 0.0226 (0.0226) | loss_objectness: 0.0001 (0.0001) | loss_rpn_box_reg: 0.0030 (0.0030) | vaqt -> 1.5629
#
# 6-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000010 | loss: 0.0375 (0.0375) | loss_classifier: 0.0129 (0.0134) | loss_box_reg: 0.0226 (0.0223) | loss_objectness: 0.0008 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0010) | vaqt -> 1.1559
#
# 6-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000010 | loss: 0.0377 (0.0401) | loss_classifier: 0.0133 (0.0142) | loss_box_reg: 0.0215 (0.0239) | loss_objectness: 0.0005 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0011) | vaqt -> 1.2064
#
# 6-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000010 | loss: 0.0452 (0.0453) | loss_classifier: 0.0140 (0.0157) | loss_box_reg: 0.0276 (0.0269) | loss_objectness: 0.0005 (0.0012) | loss_rpn_box_reg: 0.0008 (0.0015) | vaqt -> 1.2870
#
# 6-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000010 | loss: 0.0484 (0.0457) | loss_classifier: 0.0155 (0.0161) | loss_box_reg: 0.0300 (0.0274) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0007 (0.0013) | vaqt -> 1.2113
#
# 6-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000010 | loss: 0.0395 (0.0457) | loss_classifier: 0.0144 (0.0160) | loss_box_reg: 0.0217 (0.0270) | loss_objectness: 0.0004 (0.0013) | loss_rpn_box_reg: 0.0007 (0.0015) | vaqt -> 1.1157
#
# 6-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000010 | loss: 0.0419 (0.0476) | loss_classifier: 0.0155 (0.0167) | loss_box_reg: 0.0236 (0.0281) | loss_objectness: 0.0010 (0.0014) | loss_rpn_box_reg: 0.0013 (0.0014) | vaqt -> 1.1417
#
# 6-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000010 | loss: 0.0426 (0.0468) | loss_classifier: 0.0155 (0.0163) | loss_box_reg: 0.0248 (0.0278) | loss_objectness: 0.0003 (0.0013) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.1856
#
# 6-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000010 | loss: 0.0379 (0.0463) | loss_classifier: 0.0124 (0.0161) | loss_box_reg: 0.0235 (0.0276) | loss_objectness: 0.0001 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.2269
#
# 6-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000010 | loss: 0.0400 (0.0460) | loss_classifier: 0.0141 (0.0160) | loss_box_reg: 0.0252 (0.0274) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.3193
#
# 6-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000010 | loss: 0.0473 (0.0475) | loss_classifier: 0.0144 (0.0162) | loss_box_reg: 0.0299 (0.0286) | loss_objectness: 0.0003 (0.0011) | loss_rpn_box_reg: 0.0012 (0.0015) | vaqt -> 1.2945
#
# 6-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000010 | loss: 0.0526 (0.0478) | loss_classifier: 0.0165 (0.0164) | loss_box_reg: 0.0315 (0.0287) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0011 (0.0015) | vaqt -> 1.2877
#
# 6-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000010 | loss: 0.0475 (0.0478) | loss_classifier: 0.0165 (0.0163) | loss_box_reg: 0.0276 (0.0289) | loss_objectness: 0.0003 (0.0011) | loss_rpn_box_reg: 0.0011 (0.0015) | vaqt -> 1.3287
#
# 6-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000010 | loss: 0.0443 (0.0477) | loss_classifier: 0.0158 (0.0164) | loss_box_reg: 0.0252 (0.0287) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0011 (0.0015) | vaqt -> 1.2650
#
# 6-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000010 | loss: 0.0472 (0.0486) | loss_classifier: 0.0174 (0.0167) | loss_box_reg: 0.0285 (0.0293) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0011 (0.0015) | vaqt -> 1.2212
#
# 6-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000010 | loss: 0.0394 (0.0478) | loss_classifier: 0.0140 (0.0164) | loss_box_reg: 0.0252 (0.0288) | loss_objectness: 0.0001 (0.0011) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2186
#
# 6-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000010 | loss: 0.0370 (0.0479) | loss_classifier: 0.0129 (0.0165) | loss_box_reg: 0.0212 (0.0289) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0006 (0.0014) | vaqt -> 1.1742
#
# 6-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000010 | loss: 0.0436 (0.0476) | loss_classifier: 0.0140 (0.0164) | loss_box_reg: 0.0262 (0.0288) | loss_objectness: 0.0005 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.1104
#
# 6-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.000010 | loss: 0.0443 (0.0475) | loss_classifier: 0.0149 (0.0163) | loss_box_reg: 0.0281 (0.0288) | loss_objectness: 0.0005 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.0732
# 6-epochdagi  umumiy vaqt: 0:03:33 (1.2135 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6427 (0.6427) | baholash_vaqt: 0.0040 (0.0040) | vaqt -> 0.8625
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4853 (0.5226) | baholash_vaqt: 0.0030 (0.0031) | vaqt -> 0.5354
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5486 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4853 (0.5226) | baholash_vaqt: 0.0030 (0.0031)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.559
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.649
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.583
#
# 7-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000010 | loss: 0.0608 (0.0608) | loss_classifier: 0.0172 (0.0172) | loss_box_reg: 0.0405 (0.0405) | loss_objectness: 0.0017 (0.0017) | loss_rpn_box_reg: 0.0014 (0.0014) | vaqt -> 1.3674
#
# 7-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000010 | loss: 0.0546 (0.0567) | loss_classifier: 0.0172 (0.0187) | loss_box_reg: 0.0333 (0.0356) | loss_objectness: 0.0005 (0.0008) | loss_rpn_box_reg: 0.0014 (0.0015) | vaqt -> 1.2989
#
# 7-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000010 | loss: 0.0466 (0.0499) | loss_classifier: 0.0163 (0.0165) | loss_box_reg: 0.0285 (0.0309) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2546
#
# 7-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000010 | loss: 0.0393 (0.0495) | loss_classifier: 0.0148 (0.0171) | loss_box_reg: 0.0243 (0.0302) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0013) | vaqt -> 1.2069
#
# 7-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000010 | loss: 0.0401 (0.0475) | loss_classifier: 0.0148 (0.0164) | loss_box_reg: 0.0252 (0.0288) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.3012
#
# 7-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000010 | loss: 0.0401 (0.0472) | loss_classifier: 0.0131 (0.0162) | loss_box_reg: 0.0252 (0.0287) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.2752
#
# 7-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000010 | loss: 0.0414 (0.0461) | loss_classifier: 0.0142 (0.0158) | loss_box_reg: 0.0254 (0.0281) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0015) | vaqt -> 1.1566
#
# 7-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000010 | loss: 0.0405 (0.0468) | loss_classifier: 0.0144 (0.0161) | loss_box_reg: 0.0254 (0.0285) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0015) | vaqt -> 1.1358
#
# 7-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000010 | loss: 0.0453 (0.0468) | loss_classifier: 0.0149 (0.0162) | loss_box_reg: 0.0265 (0.0285) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.1211
#
# 7-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000010 | loss: 0.0424 (0.0465) | loss_classifier: 0.0131 (0.0160) | loss_box_reg: 0.0225 (0.0283) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0006 (0.0013) | vaqt -> 1.1697
#
# 7-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000010 | loss: 0.0400 (0.0472) | loss_classifier: 0.0134 (0.0163) | loss_box_reg: 0.0262 (0.0286) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.1781
#
# 7-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000010 | loss: 0.0400 (0.0470) | loss_classifier: 0.0137 (0.0163) | loss_box_reg: 0.0262 (0.0284) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.1702
#
# 7-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000010 | loss: 0.0334 (0.0469) | loss_classifier: 0.0122 (0.0163) | loss_box_reg: 0.0204 (0.0283) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0015) | vaqt -> 1.2307
#
# 7-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000010 | loss: 0.0293 (0.0471) | loss_classifier: 0.0117 (0.0163) | loss_box_reg: 0.0169 (0.0285) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.2271
#
# 7-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000010 | loss: 0.0342 (0.0475) | loss_classifier: 0.0137 (0.0164) | loss_box_reg: 0.0220 (0.0288) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.2370
#
# 7-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000010 | loss: 0.0500 (0.0474) | loss_classifier: 0.0156 (0.0163) | loss_box_reg: 0.0320 (0.0288) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2174
#
# 7-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000010 | loss: 0.0395 (0.0473) | loss_classifier: 0.0160 (0.0164) | loss_box_reg: 0.0246 (0.0288) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.1680
#
# 7-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000010 | loss: 0.0400 (0.0471) | loss_classifier: 0.0154 (0.0163) | loss_box_reg: 0.0256 (0.0287) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2331
#
# 7-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.000010 | loss: 0.0426 (0.0477) | loss_classifier: 0.0153 (0.0164) | loss_box_reg: 0.0265 (0.0291) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.1711
# 7-epochdagi  umumiy vaqt: 0:03:32 (1.2070 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6451 (0.6451) | baholash_vaqt: 0.0040 (0.0040) | vaqt -> 0.8872
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4817 (0.5238) | baholash_vaqt: 0.0028 (0.0030) | vaqt -> 0.5368
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5501 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4817 (0.5238) | baholash_vaqt: 0.0028 (0.0030)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.543
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.649
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.583
#
# 8-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000010 | loss: 0.0388 (0.0388) | loss_classifier: 0.0114 (0.0114) | loss_box_reg: 0.0271 (0.0271) | loss_objectness: 0.0000 (0.0000) | loss_rpn_box_reg: 0.0003 (0.0003) | vaqt -> 1.6054
#
# 8-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000010 | loss: 0.0431 (0.0462) | loss_classifier: 0.0151 (0.0174) | loss_box_reg: 0.0266 (0.0274) | loss_objectness: 0.0002 (0.0004) | loss_rpn_box_reg: 0.0009 (0.0010) | vaqt -> 1.4549
#
# 8-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000010 | loss: 0.0427 (0.0450) | loss_classifier: 0.0151 (0.0156) | loss_box_reg: 0.0259 (0.0276) | loss_objectness: 0.0004 (0.0006) | loss_rpn_box_reg: 0.0009 (0.0012) | vaqt -> 1.2846
#
# 8-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000010 | loss: 0.0427 (0.0481) | loss_classifier: 0.0152 (0.0166) | loss_box_reg: 0.0263 (0.0296) | loss_objectness: 0.0002 (0.0006) | loss_rpn_box_reg: 0.0012 (0.0013) | vaqt -> 1.1771
#
# 8-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000010 | loss: 0.0429 (0.0475) | loss_classifier: 0.0155 (0.0161) | loss_box_reg: 0.0259 (0.0292) | loss_objectness: 0.0001 (0.0006) | loss_rpn_box_reg: 0.0014 (0.0015) | vaqt -> 1.2930
#
# 8-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000010 | loss: 0.0419 (0.0473) | loss_classifier: 0.0130 (0.0161) | loss_box_reg: 0.0234 (0.0291) | loss_objectness: 0.0003 (0.0007) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.2059
#
# 8-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000010 | loss: 0.0367 (0.0471) | loss_classifier: 0.0130 (0.0160) | loss_box_reg: 0.0228 (0.0290) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0007 (0.0013) | vaqt -> 1.0858
#
# 8-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000010 | loss: 0.0366 (0.0476) | loss_classifier: 0.0131 (0.0160) | loss_box_reg: 0.0228 (0.0295) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0013) | vaqt -> 1.2058
#
# 8-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000010 | loss: 0.0323 (0.0460) | loss_classifier: 0.0119 (0.0156) | loss_box_reg: 0.0209 (0.0284) | loss_objectness: 0.0001 (0.0007) | loss_rpn_box_reg: 0.0012 (0.0013) | vaqt -> 1.2883
#
# 8-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000010 | loss: 0.0346 (0.0454) | loss_classifier: 0.0130 (0.0153) | loss_box_reg: 0.0216 (0.0280) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0008 (0.0013) | vaqt -> 1.2622
#
# 8-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000010 | loss: 0.0381 (0.0447) | loss_classifier: 0.0129 (0.0150) | loss_box_reg: 0.0224 (0.0275) | loss_objectness: 0.0004 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0013) | vaqt -> 1.2013
#
# 8-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000010 | loss: 0.0381 (0.0453) | loss_classifier: 0.0129 (0.0153) | loss_box_reg: 0.0237 (0.0277) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0012 (0.0014) | vaqt -> 1.1533
#
# 8-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000010 | loss: 0.0519 (0.0456) | loss_classifier: 0.0186 (0.0155) | loss_box_reg: 0.0327 (0.0279) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.1657
#
# 8-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000010 | loss: 0.0413 (0.0454) | loss_classifier: 0.0157 (0.0156) | loss_box_reg: 0.0231 (0.0276) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0006 (0.0014) | vaqt -> 1.1384
#
# 8-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000010 | loss: 0.0413 (0.0462) | loss_classifier: 0.0144 (0.0159) | loss_box_reg: 0.0250 (0.0280) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.2158
#
# 8-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000010 | loss: 0.0423 (0.0459) | loss_classifier: 0.0143 (0.0158) | loss_box_reg: 0.0272 (0.0279) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.2415
#
# 8-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000010 | loss: 0.0423 (0.0467) | loss_classifier: 0.0141 (0.0161) | loss_box_reg: 0.0272 (0.0284) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.1720
#
# 8-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000010 | loss: 0.0495 (0.0469) | loss_classifier: 0.0166 (0.0161) | loss_box_reg: 0.0298 (0.0286) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0015 (0.0014) | vaqt -> 1.2241
#
# 8-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.000010 | loss: 0.0495 (0.0473) | loss_classifier: 0.0178 (0.0162) | loss_box_reg: 0.0300 (0.0289) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.1470
# 8-epochdagi  umumiy vaqt: 0:03:33 (1.2127 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6448 (0.6448) | baholash_vaqt: 0.0042 (0.0042) | vaqt -> 0.8951
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4762 (0.5246) | baholash_vaqt: 0.0030 (0.0031) | vaqt -> 0.5381
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5518 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4762 (0.5246) | baholash_vaqt: 0.0030 (0.0031)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.543
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.579
#
# 9-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000001 | loss: 0.0828 (0.0828) | loss_classifier: 0.0212 (0.0212) | loss_box_reg: 0.0594 (0.0594) | loss_objectness: 0.0005 (0.0005) | loss_rpn_box_reg: 0.0018 (0.0018) | vaqt -> 1.2621
#
# 9-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000001 | loss: 0.0696 (0.0675) | loss_classifier: 0.0204 (0.0217) | loss_box_reg: 0.0433 (0.0430) | loss_objectness: 0.0004 (0.0009) | loss_rpn_box_reg: 0.0018 (0.0018) | vaqt -> 1.4053
#
# 9-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000001 | loss: 0.0405 (0.0524) | loss_classifier: 0.0143 (0.0173) | loss_box_reg: 0.0247 (0.0330) | loss_objectness: 0.0004 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0013) | vaqt -> 1.3779
#
# 9-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000001 | loss: 0.0380 (0.0523) | loss_classifier: 0.0143 (0.0181) | loss_box_reg: 0.0226 (0.0318) | loss_objectness: 0.0004 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0016) | vaqt -> 1.2703
#
# 9-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000001 | loss: 0.0385 (0.0490) | loss_classifier: 0.0131 (0.0168) | loss_box_reg: 0.0248 (0.0300) | loss_objectness: 0.0001 (0.0007) | loss_rpn_box_reg: 0.0010 (0.0015) | vaqt -> 1.1886
#
# 9-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000001 | loss: 0.0381 (0.0493) | loss_classifier: 0.0111 (0.0167) | loss_box_reg: 0.0264 (0.0303) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0015) | vaqt -> 1.1793
#
# 9-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000001 | loss: 0.0392 (0.0479) | loss_classifier: 0.0142 (0.0162) | loss_box_reg: 0.0264 (0.0294) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0015) | vaqt -> 1.1507
#
# 9-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000001 | loss: 0.0392 (0.0469) | loss_classifier: 0.0138 (0.0161) | loss_box_reg: 0.0218 (0.0285) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0009 (0.0015) | vaqt -> 1.1267
#
# 9-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000001 | loss: 0.0443 (0.0475) | loss_classifier: 0.0154 (0.0161) | loss_box_reg: 0.0263 (0.0290) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0009 (0.0015) | vaqt -> 1.1648
#
# 9-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000001 | loss: 0.0489 (0.0479) | loss_classifier: 0.0165 (0.0163) | loss_box_reg: 0.0327 (0.0293) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.2405
#
# 9-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000001 | loss: 0.0489 (0.0482) | loss_classifier: 0.0181 (0.0164) | loss_box_reg: 0.0323 (0.0296) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.2167
#
# 9-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000001 | loss: 0.0462 (0.0478) | loss_classifier: 0.0158 (0.0162) | loss_box_reg: 0.0273 (0.0294) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2031
#
# 9-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000001 | loss: 0.0363 (0.0476) | loss_classifier: 0.0149 (0.0162) | loss_box_reg: 0.0221 (0.0291) | loss_objectness: 0.0005 (0.0009) | loss_rpn_box_reg: 0.0009 (0.0015) | vaqt -> 1.2581
#
# 9-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000001 | loss: 0.0363 (0.0473) | loss_classifier: 0.0150 (0.0161) | loss_box_reg: 0.0218 (0.0289) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2232
#
# 9-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000001 | loss: 0.0368 (0.0470) | loss_classifier: 0.0129 (0.0160) | loss_box_reg: 0.0219 (0.0288) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.2769
#
# 9-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000001 | loss: 0.0368 (0.0465) | loss_classifier: 0.0124 (0.0159) | loss_box_reg: 0.0227 (0.0284) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.2270
#
# 9-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000001 | loss: 0.0392 (0.0470) | loss_classifier: 0.0150 (0.0162) | loss_box_reg: 0.0236 (0.0286) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.1937
#
# 9-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000001 | loss: 0.0499 (0.0471) | loss_classifier: 0.0170 (0.0163) | loss_box_reg: 0.0273 (0.0286) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.1918
#
# 9-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.000001 | loss: 0.0411 (0.0472) | loss_classifier: 0.0169 (0.0163) | loss_box_reg: 0.0231 (0.0287) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.1269
# 9-epochdagi  umumiy vaqt: 0:03:34 (1.2169 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6694 (0.6694) | baholash_vaqt: 0.0041 (0.0041) | vaqt -> 0.9046
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4859 (0.5247) | baholash_vaqt: 0.0029 (0.0031) | vaqt -> 0.5365
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5510 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4859 (0.5247) | baholash_vaqt: 0.0029 (0.0031)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.543
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.579
#
# 10-epochdagi 176ta batchdan   1-sining natijasi:
#
# lr: 0.000001 | loss: 0.0406 (0.0406) | loss_classifier: 0.0161 (0.0161) | loss_box_reg: 0.0215 (0.0215) | loss_objectness: 0.0011 (0.0011) | loss_rpn_box_reg: 0.0018 (0.0018) | vaqt -> 1.3819
#
# 10-epochdagi 176ta batchdan  11-sining natijasi:
#
# lr: 0.000001 | loss: 0.0533 (0.0530) | loss_classifier: 0.0221 (0.0201) | loss_box_reg: 0.0303 (0.0311) | loss_objectness: 0.0003 (0.0005) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.2759
#
# 10-epochdagi 176ta batchdan  21-sining natijasi:
#
# lr: 0.000001 | loss: 0.0533 (0.0530) | loss_classifier: 0.0190 (0.0194) | loss_box_reg: 0.0320 (0.0317) | loss_objectness: 0.0003 (0.0006) | loss_rpn_box_reg: 0.0009 (0.0013) | vaqt -> 1.2596
#
# 10-epochdagi 176ta batchdan  31-sining natijasi:
#
# lr: 0.000001 | loss: 0.0505 (0.0508) | loss_classifier: 0.0155 (0.0178) | loss_box_reg: 0.0344 (0.0311) | loss_objectness: 0.0002 (0.0005) | loss_rpn_box_reg: 0.0012 (0.0013) | vaqt -> 1.3039
#
# 10-epochdagi 176ta batchdan  41-sining natijasi:
#
# lr: 0.000001 | loss: 0.0427 (0.0524) | loss_classifier: 0.0138 (0.0181) | loss_box_reg: 0.0230 (0.0317) | loss_objectness: 0.0004 (0.0008) | loss_rpn_box_reg: 0.0011 (0.0017) | vaqt -> 1.2602
#
# 10-epochdagi 176ta batchdan  51-sining natijasi:
#
# lr: 0.000001 | loss: 0.0382 (0.0499) | loss_classifier: 0.0132 (0.0174) | loss_box_reg: 0.0209 (0.0301) | loss_objectness: 0.0004 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0016) | vaqt -> 1.1764
#
# 10-epochdagi 176ta batchdan  61-sining natijasi:
#
# lr: 0.000001 | loss: 0.0364 (0.0492) | loss_classifier: 0.0132 (0.0170) | loss_box_reg: 0.0243 (0.0299) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0015) | vaqt -> 1.1932
#
# 10-epochdagi 176ta batchdan  71-sining natijasi:
#
# lr: 0.000001 | loss: 0.0447 (0.0489) | loss_classifier: 0.0123 (0.0166) | loss_box_reg: 0.0305 (0.0300) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.1785
#
# 10-epochdagi 176ta batchdan  81-sining natijasi:
#
# lr: 0.000001 | loss: 0.0447 (0.0487) | loss_classifier: 0.0130 (0.0164) | loss_box_reg: 0.0282 (0.0299) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0011 (0.0014) | vaqt -> 1.1921
#
# 10-epochdagi 176ta batchdan  91-sining natijasi:
#
# lr: 0.000001 | loss: 0.0457 (0.0483) | loss_classifier: 0.0140 (0.0165) | loss_box_reg: 0.0270 (0.0295) | loss_objectness: 0.0005 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0014) | vaqt -> 1.2758
#
# 10-epochdagi 176ta batchdan 101-sining natijasi:
#
# lr: 0.000001 | loss: 0.0431 (0.0480) | loss_classifier: 0.0151 (0.0164) | loss_box_reg: 0.0261 (0.0294) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0009 (0.0013) | vaqt -> 1.2974
#
# 10-epochdagi 176ta batchdan 111-sining natijasi:
#
# lr: 0.000001 | loss: 0.0426 (0.0486) | loss_classifier: 0.0151 (0.0165) | loss_box_reg: 0.0265 (0.0297) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0013) | vaqt -> 1.2620
#
# 10-epochdagi 176ta batchdan 121-sining natijasi:
#
# lr: 0.000001 | loss: 0.0410 (0.0477) | loss_classifier: 0.0122 (0.0162) | loss_box_reg: 0.0267 (0.0293) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0006 (0.0013) | vaqt -> 1.1611
#
# 10-epochdagi 176ta batchdan 131-sining natijasi:
#
# lr: 0.000001 | loss: 0.0336 (0.0475) | loss_classifier: 0.0118 (0.0162) | loss_box_reg: 0.0209 (0.0291) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0007 (0.0013) | vaqt -> 1.1587
#
# 10-epochdagi 176ta batchdan 141-sining natijasi:
#
# lr: 0.000001 | loss: 0.0453 (0.0473) | loss_classifier: 0.0129 (0.0160) | loss_box_reg: 0.0254 (0.0290) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0009 (0.0014) | vaqt -> 1.2753
#
# 10-epochdagi 176ta batchdan 151-sining natijasi:
#
# lr: 0.000001 | loss: 0.0487 (0.0473) | loss_classifier: 0.0143 (0.0161) | loss_box_reg: 0.0282 (0.0289) | loss_objectness: 0.0004 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0014) | vaqt -> 1.2274
#
# 10-epochdagi 176ta batchdan 161-sining natijasi:
#
# lr: 0.000001 | loss: 0.0441 (0.0472) | loss_classifier: 0.0144 (0.0160) | loss_box_reg: 0.0281 (0.0289) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0007 (0.0014) | vaqt -> 1.1805
#
# 10-epochdagi 176ta batchdan 171-sining natijasi:
#
# lr: 0.000001 | loss: 0.0414 (0.0470) | loss_classifier: 0.0139 (0.0160) | loss_box_reg: 0.0262 (0.0288) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0006 (0.0014) | vaqt -> 1.2061
#
# 10-epochdagi 176ta batchdan 176-sining natijasi:
#
# lr: 0.000001 | loss: 0.0415 (0.0475) | loss_classifier: 0.0144 (0.0161) | loss_box_reg: 0.0278 (0.0291) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0006 (0.0014) | vaqt -> 1.1649
# 10-epochdagi  umumiy vaqt: 0:03:35 (1.2226 s / rasm)
# creating index...
# index created!
#
# Test jarayoni: 22ta batchdan  1-sining natijasi:
#
# model_vaqt: 0.6413 (0.6413) | baholash_vaqt: 0.0040 (0.0040) | vaqt -> 0.8998
#
# Test jarayoni: 22ta batchdan 22-sining natijasi:
#
# model_vaqt: 0.4810 (0.5257) | baholash_vaqt: 0.0029 (0.0031) | vaqt -> 0.5378
# Test jarayoni:  umumiy vaqt: 0:00:12 (0.5524 s / rasm)
#
# Test jarayoni statistikasi: model_vaqt: 0.4810 (0.5257) | baholash_vaqt: 0.0029 (0.0031)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.543
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.579
# Train jarayoni yakunlandi!

# %% [markdown]
# ### Inference

# %%
def inference(model, ts_dl, num_ims, rows, threshold = 0.3, cmap = None):

    assert cmap in ["rgb", "gray"], "Rasmni oq-qora yoki rangli ekanini aniqlashtirib bering!"
    if cmap == "rgb": cmap = "viridis"

    plt.figure(figsize = (20, 10))
    indekslar = [random.randint(0, len(ts_dl) - 1) for _ in range(num_ims)]

    for idx, indeks in enumerate(indekslar):
        im, _ = ts_dl.dataset[indeks]
        with torch.no_grad(): predictions = m(im.unsqueeze(0).to(device))
        img = tensor_2_im(im, inv_trans = True)
        bbox_class_names = []
        for i, (boxes, scores, labels) in enumerate(zip(predictions[0]["boxes"], predictions[0]["scores"], predictions[0]["labels"])):
            if scores > threshold:
                bbox_class_names.append(list(class_names.keys())[labels.item()])
                r, g, b = [random.randint(0, 255) for _ in range(3)]
                x, y, w, h = [round(b.item()) for b in boxes]
                cv2.rectangle(img = img, pt1 = (x, y), pt2 = (w, h), color = (r, g, b), thickness = 2)
        plt.subplot(rows, num_ims // rows, idx + 1)
        plt.imshow(img); plt.title(f"{bbox_class_names}")
        plt.axis("off")

inference(model = m, ts_dl = ts_dl, num_ims = 12, rows = 3, cmap = "rgb")
